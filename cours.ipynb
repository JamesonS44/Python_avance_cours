# %% [markdown]
# Commandes git:
# - git clone // pour cloner un repertoire depuis un url github
# - git add ... // permet de tracker les modifications d'un fichier
# - git commit // pour soumettre une version
# - git push // envoyer
# - git pull // recevoir

# %% [markdown]
# Commandes git:
# - git clone // pour cloner un repertoire depuis un url github
# - git add ... // permet de tracker les modifications d'un fichier
# - git commit // pour soumettre une version
# - git push // envoyer
# - git pull // recevoir
